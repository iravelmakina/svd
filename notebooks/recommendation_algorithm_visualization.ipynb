# %%
import numpy as np
import pandas as pd
from scipy.sparse.linalg import svds
import matplotlib.pyplot as plt

from src.objects import file_path_ratings as ratings

# %%
df = pd.read_csv(ratings)
ratings_matrix = df.pivot(index='userId', columns='movieId', values='rating')
ratings_matrix.shape
# Out:
# (610, 9724)

# %%
ratings_matrix = ratings_matrix.dropna(thresh=200, axis=0)
ratings_matrix = ratings_matrix.dropna(thresh=90, axis=1)
ratings_matrix.shape
# Out:
# (134, 23)

# %%
ratings_matrix_filled = ratings_matrix.fillna(2.5)
ratings_array = ratings_matrix_filled.values  # transform into np.array
user_ratings_mean = np.mean(ratings_array, axis=1)
ratings_array_demeaned = ratings_array - user_ratings_mean.reshape(-1, 1)

# %%
u, sigma, vt = svds(ratings_array_demeaned, k=3) # where k is some latent feature, k is used to reduce dimensionality and computations

# %%
print((f"Matrix U:\n", u))
u.shape
# Out:
# ('Matrix U:\n', array([[-0.07929906,  0.08846686, -0.04643066],
#        [-0.08024469,  0.06448968, -0.04612266],
#        [ 0.17526646, -0.04748009,  0.03412667],
#        [-0.0118056 ,  0.00460939, -0.05062444],
#        [-0.10198388,  0.054064  , -0.05247545],
#        [-0.07143422, -0.03758198,  0.01123065],
#        [ 0.13533147,  0.2229471 ,  0.03050778],
#        [-0.07220342,  0.01128235, -0.04488329],
#        [-0.04670882, -0.0953034 , -0.06584231],
#        [ 0.06888399,  0.06015489, -0.10946165],
#        [-0.19527464,  0.01598171, -0.06535723],
#        [ 0.05762231, -0.02304814, -0.04952773],
#        [-0.10008306,  0.08594536,  0.00604216],
#        [-0.0866912 ,  0.05957719,  0.00675476],
#        [-0.02731559,  0.01670579, -0.09029002],
#        [ 0.0271892 ,  0.08820067, -0.15171735],
#        [ 0.04092573, -0.05692501, -0.07686367],
#        [-0.03340779, -0.14042878, -0.10320715],
#        [-0.14396092,  0.11642978, -0.0006136 ],
#        [-0.03668417, -0.06220688, -0.00249978],
#        [-0.0379473 ,  0.0982416 ,  0.06330685],
#        [ 0.13695099,  0.06959906, -0.1021627 ],
#        [-0.10360615, -0.01267006,  0.00146013],
#        [-0.11907209,  0.06548649, -0.0064474 ],
#        [ 0.05469789, -0.00233983, -0.11761118],
#        [ 0.05494629, -0.00883007,  0.03116813],
#        [-0.07875068, -0.14274732, -0.1339295 ],
#        [ 0.13153617, -0.06800116, -0.04829673],
#        [ 0.06850152, -0.0555843 , -0.0259633 ],
#        [ 0.0800549 ,  0.0678837 , -0.12424451],
#        [ 0.10058561, -0.06465103, -0.12275579],
#        [ 0.05200521, -0.13799993, -0.11839181],
#        [-0.01187039, -0.0124435 , -0.10170901],
#        [ 0.00556886, -0.01338034,  0.00098097],
#        [ 0.1291618 , -0.10199381, -0.06435604],
#        [-0.2089564 ,  0.05839746, -0.1285746 ],
#        [ 0.13225004, -0.04955716,  0.02409625],
#        [ 0.2442899 , -0.05030202, -0.09315348],
#        [ 0.03626404, -0.11558351, -0.1826251 ],
#        [-0.06776147,  0.13221504,  0.06134295],
#        [-0.08715331,  0.05016577, -0.17497121],
#        [ 0.07668156,  0.09048673, -0.19727659],
#        [-0.09445523, -0.05136945, -0.05376934],
#        [ 0.02121201,  0.07840054, -0.10223594],
#        [ 0.03856251,  0.0190057 , -0.07135438],
#        [ 0.01471838, -0.01988847, -0.09529684],
#        [-0.07351347,  0.19615661,  0.07450042],
#        [-0.08606306,  0.02252648, -0.1172595 ],
#        [ 0.12730579,  0.16854242,  0.01432033],
#        [ 0.02286207, -0.1142555 , -0.1180211 ],
#        [-0.00814149, -0.02176235, -0.04295608],
#        [-0.05623984,  0.11493916, -0.06620657],
#        [-0.0501338 ,  0.03235383, -0.04131359],
#        [-0.05867518,  0.19807667,  0.01003144],
#        [-0.05589866,  0.0061979 , -0.08855159],
#        [-0.1355226 ,  0.13667087, -0.1033943 ],
#        [-0.02274022,  0.03852453, -0.05215217],
#        [ 0.04817983, -0.02929446, -0.07209927],
#        [ 0.01334183, -0.04547752, -0.10422297],
#        [ 0.02960752, -0.04013902, -0.11131215],
#        [ 0.05138898, -0.0889098 , -0.04119188],
#        [ 0.14536478,  0.12804219, -0.12511358],
#        [ 0.02827798,  0.06113689, -0.11473246],
#        [ 0.09100928,  0.07791999,  0.0510975 ],
#        [ 0.03931512,  0.1322605 , -0.02431397],
#        [-0.06731332,  0.04771708, -0.08988419],
#        [ 0.15889145,  0.19654352,  0.02042318],
#        [-0.09129743, -0.00117451, -0.14028884],
#        [ 0.08829686, -0.03329526, -0.08852606],
#        [-0.09508385,  0.16050006, -0.03121892],
#        [-0.21591559, -0.08758424, -0.08200463],
#        [ 0.08218592, -0.02659171, -0.02275188],
#        [ 0.04944749, -0.04110991, -0.09713395],
#        [ 0.13428302,  0.12215218, -0.1405579 ],
#        [ 0.02944661,  0.02501348, -0.09992414],
#        [ 0.01086057, -0.07511827, -0.12017555],
#        [-0.00136746, -0.12574874, -0.03533229],
#        [-0.05256009, -0.11292434, -0.1414104 ],
#        [ 0.03865561, -0.01134227, -0.05944453],
#        [ 0.03371171, -0.09267201, -0.06684481],
#        [ 0.01043004, -0.00273741, -0.01580917],
#        [ 0.13823664,  0.07681304, -0.03341266],
#        [-0.09762439,  0.01723671, -0.06937551],
#        [ 0.11827978,  0.1461716 , -0.08640378],
#        [-0.01197147,  0.10165719,  0.01233361],
#        [ 0.02727445,  0.00642253,  0.01414056],
#        [ 0.04442525,  0.0619474 , -0.15872843],
#        [ 0.14718088,  0.15142171, -0.06077192],
#        [-0.05827938,  0.03123523, -0.15540406],
#        [ 0.07246566,  0.098553  , -0.25886922],
#        [-0.01754337,  0.03645383, -0.07158997],
#        [ 0.02004618, -0.09120802, -0.04428514],
#        [-0.10110004, -0.02136821, -0.06940788],
#        [-0.07343592, -0.02213978, -0.01410881],
#        [-0.10453827, -0.00267095, -0.15660977],
#        [-0.00882277,  0.10301299,  0.00313668],
#        [-0.03341552,  0.11016462, -0.07370771],
#        [-0.08330745,  0.11004085,  0.06488792],
#        [ 0.00192525, -0.11169526, -0.04520538],
#        [ 0.01132175, -0.04811342, -0.06949105],
#        [-0.0136045 ,  0.00948416, -0.10431388],
#        [ 0.01041713,  0.02479759, -0.00719929],
#        [ 0.07457887,  0.06553845, -0.0365004 ],
#        [-0.00922089,  0.03158434, -0.0955761 ],
#        [ 0.05187944,  0.04272675, -0.11870829],
#        [ 0.12066643, -0.12143382, -0.03198547],
#        [ 0.02055912, -0.03797778, -0.11582714],
#        [ 0.02884145, -0.13368177,  0.00054417],
#        [-0.09169999,  0.04661035, -0.02968444],
#        [-0.01795433,  0.14354442, -0.06733135],
#        [ 0.20704746,  0.05814022, -0.0088682 ],
#        [ 0.03064034,  0.03044077, -0.08437576],
#        [ 0.07056599,  0.06708903, -0.06265722],
#        [-0.04022093,  0.0870097 ,  0.0622098 ],
#        [ 0.00317832,  0.04222534, -0.06549171],
#        [-0.13240232, -0.01362807, -0.02315724],
#        [-0.01392083,  0.0455012 , -0.07034113],
#        [ 0.04995567, -0.15114819, -0.13649241],
#        [ 0.06118156,  0.00955634, -0.00783621],
#        [ 0.02593031, -0.04223724, -0.03542703],
#        [ 0.0082992 ,  0.09227809, -0.01318281],
#        [-0.07440077, -0.0627886 , -0.07769947],
#        [-0.03961632,  0.1314512 , -0.02291448],
#        [ 0.02384645,  0.10226145, -0.0529897 ],
#        [-0.11541011, -0.03720269,  0.12122342],
#        [-0.04045459,  0.05532271, -0.04660276],
#        [-0.03579938,  0.17718758, -0.03320138],
#        [-0.09226774,  0.04484514, -0.10675573],
#        [-0.01236519,  0.03411404, -0.16642274],
#        [-0.14837652, -0.08784701, -0.11004564],
#        [-0.01356309,  0.12580207,  0.01639014],
#        [-0.12292755, -0.00485418, -0.13206416],
#        [-0.12510393, -0.11503365, -0.08513978],
#        [-0.1395746 ,  0.07075285, -0.05639294]]))
# (134, 3)

# %%
print(f"Matrix V:\n", vt.T)
vt.shape
# Out:
# Matrix V:
#  [[ 0.2008885   0.04341405  0.10492478]
#  [-0.16586881  0.44420704 -0.14336327]
#  [ 0.05876658 -0.10546453 -0.36910095]
#  [ 0.51118772 -0.17923098 -0.24891032]
#  [ 0.38628851 -0.01776183 -0.12618934]
#  [ 0.04356422  0.02499853  0.2274465 ]
#  [-0.15291014  0.10474017  0.06890595]
#  [ 0.00429754 -0.17065776 -0.12140548]
#  [ 0.11056749 -0.10682701  0.4332501 ]
#  [-0.12263309  0.41454018 -0.16042126]
#  [-0.02260226  0.23264522 -0.0187348 ]
#  [-0.10963814  0.38817031 -0.04927679]
#  [ 0.18312936 -0.02043614 -0.03485636]
#  [ 0.30360312  0.19730754  0.01686429]
#  [ 0.09312027  0.01819575  0.29970202]
#  [-0.18805048 -0.07718966  0.05077767]
#  [-0.206808   -0.02631928 -0.15907912]
#  [ 0.08525052 -0.04556327  0.44660896]
#  [-0.23380688 -0.19707292  0.10976022]
#  [-0.21761974 -0.31307633 -0.18539116]
#  [-0.08591254 -0.29799606 -0.27284408]
#  [-0.31204291 -0.21077691  0.16244726]
#  [-0.16277086 -0.09984611 -0.03111481]]
# (3, 23)

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(u[:20, 0], u[:20, 1], u[:20, 2], c='blue', marker='o')
plt.title('Visualization of Users')
ax.set_xlabel('Latent Feature 1')
ax.set_ylabel('Latent Feature 2')
ax.set_zlabel('Latent Feature 3')
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(vt.T[:20, 0], vt.T[:20, 1], vt.T[:20, 2], c='red', marker='o')
plt.title('Visualization of Movies')
ax.set_xlabel('Latent Feature 1')
ax.set_ylabel('Latent Feature 2')
ax.set_zlabel('Latent Feature 3')
plt.show()
